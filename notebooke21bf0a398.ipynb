# %% [markdown]
# # **DATA VISUALIZATION**

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
 #loading data
df = pd.read_csv('/kaggle/input/datasets/muniryadi/gasturbine-co-and-nox-emission-data/gt_full.csv')
df.head()
# Out:
#    Unnamed: 0      AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY  \
# 0           1  4.5878  1018.7  83.675  3.5758  23.979  1086.2  549.83  134.67
# 1           2  4.2932  1018.3  84.235  3.5709  23.951  1086.1  550.05  134.67
# 2           3  3.9045  1018.4  84.858  3.5828  23.990  1086.5  550.19  135.10
# 3           4  3.7436  1018.3  85.434  3.5808  23.911  1086.5  550.17  135.03
# 4           5  3.7516  1017.8  85.182  3.5781  23.917  1085.9  550.00  134.67
#
#       CDP       CO     NOX
# 0  11.898  0.32663  81.952
# 1  11.892  0.44784  82.377
# 2  12.042  0.45144  83.776
# 3  11.990  0.23107  82.505
# 4  11.910  0.26747  82.028

# %%
df.shape
# Out:
# (36733, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY',
#        'CDP', 'CO', 'NOX'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36733 entries, 0 to 36732
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  36733 non-null  int64
#  1   AT          36733 non-null  float64
#  2   AP          36733 non-null  float64
#  3   AH          36733 non-null  float64
#  4   AFDP        36733 non-null  float64
#  5   GTEP        36733 non-null  float64
#  6   TIT         36733 non-null  float64
#  7   TAT         36733 non-null  float64
#  8   TEY         36733 non-null  float64
#  9   CDP         36733 non-null  float64
#  10  CO          36733 non-null  float64
#  11  NOX         36733 non-null  float64
# dtypes: float64(11), int64(1)
# memory usage: 3.4 MB

# %%
df.describe()
# Out:
#          Unnamed: 0            AT            AP            AH          AFDP  \
# count  36733.000000  36733.000000  36733.000000  36733.000000  36733.000000
# mean   18367.000000     17.712726   1013.070165     77.867015      3.925518
# std    10604.048056      7.447451      6.463346     14.461355      0.773936
# min        1.000000     -6.234800    985.850000     24.085000      2.087400
# 25%     9184.000000     11.781000   1008.800000     68.188000      3.355600
# 50%    18367.000000     17.801000   1012.600000     80.470000      3.937700
# 75%    27550.000000     23.665000   1017.000000     89.376000      4.376900
# max    36733.000000     37.103000   1036.600000    100.200000      7.610600
#
#                GTEP           TIT           TAT           TEY           CDP  \
# count  36733.000000  36733.000000  36733.000000  36733.000000  36733.000000
# mean      25.563801   1081.428084    546.158517    133.506404     12.060525
# ...

# %%
#checking for null or missing values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# AT            0
# AP            0
# AH            0
# AFDP          0
# GTEP          0
# TIT           0
# TAT           0
# TEY           0
# CDP           0
# CO            0
# NOX           0
# dtype: int64

# %% [markdown]
# no null value found here.

# %%
df.hist(figsize=(12,10))
plt.show()

# %% [markdown]
# CO histogram is highly skewed, most of the values are near zero. Overall the data is almost well distributed.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
sns.scatterplot(x=df['AT'], y=df['CO'])
plt.title("Ambient Temperature vs CO Emission")
plt.show()

# %%
sns.scatterplot(x=df['AT'], y=df['NOX'])
plt.title("Ambient Temperature vs NOx Emission")
plt.show()

# %%
sns.boxplot(data=df[['CO','NOX']])
plt.title("Distribution of CO and NOx Emissions")
plt.show()

# %% [markdown]
# CO: Most values are near zero. many outliers are found.
# NOx: the data is well distributed and have few outliers.

# %%
sns.pairplot(df[['AT','AP','AH','CO','NOX']])
plt.show()

# %% [markdown]
# # **PREPROCESSING**

# %%
# Drop column
if 'Unnamed: 0' in df.columns:
    df = df.drop(['Unnamed: 0'], axis=1)

# Verification
df.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %% [markdown]
# As unnamed column do not have any predictive meaning.Its just been used for indexing.

# %%
# Features Scaling
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

df_scaled = pd.DataFrame(scaled_data, columns=df.columns)
# Shows first 5 rows of scaled dataset
df_scaled.head()
# Out:
#          AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 0 -1.762362  0.871052  0.401627 -0.451875 -0.377702  0.272119  0.536589
# 1 -1.801920  0.809164  0.440351 -0.458207 -0.384376  0.266417  0.568742
# 2 -1.854113  0.824636  0.483432 -0.442831 -0.375081  0.289227  0.589203
# 3 -1.875718  0.809164  0.523263 -0.445415 -0.393909  0.289227  0.586280
# 4 -1.874644  0.731804  0.505837 -0.448904 -0.392479  0.255012  0.561434
#
#         TEY       CDP        CO       NOX
# 0  0.074502 -0.149273 -0.904182  1.426499
# 1  0.074502 -0.154783 -0.850611  1.462891
# 2  0.102033 -0.017015 -0.849020  1.582687
# 3  0.097551 -0.064774 -0.946415  1.473852
# 4  0.074502 -0.138251 -0.930328  1.433006

# %%
df_scaled.to_csv("preprocessed_gasturbine_data.csv", index=False)
